# %% [markdown]
# <a href="https://colab.research.google.com/github/wbr179/MNIST-Neural-Network-from-scratch-NumPy-Implementation-/blob/main/O_1888_workbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Online Training - Deep Learning (K4.0016_3.0)**
# *16.02.2026 - David Lewenko - velpTEC*
#
# ---

# %% [markdown]
# # **0 - Grundlagenwissen zu diesem Workbook**
# ### ⚙️ 1. Was ist Machine Learning?
#
# - **Definition:** Beim Machine Learning bringen wir Computern bei, aus Daten zu lernen, statt ihnen jede Regel einzeln vorzuschreiben.
# - **Arten:**
#   - Supervised Learning (z. B. Titanic: Wir wissen, wer überlebt hat)
#   - Unsupervised Learning (z. B. Gruppen entdecken)
#   - Reinforcement Learning (z. B. Lernen durch Ausprobieren)
#
# ---
#
# ### 📦 2. Ablauf eines Machine-Learning-Projekts
#
# - Typische Schritte:
#   1. Verstehen, worum es geht
#   2. Daten laden
#   3. Daten anschauen und aufräumen
#   4. Neue Merkmale (Features) bauen
#   5. Modelle trainieren
#   6. Modelle testen und verbessern
#   7. Vorhersagen machen
#
#
# ---
#
# ### 📊 3. Was ist ein Datensatz?
#
# - **Datensatz = Tabelle**
# - **Zeile = ein Passagier**
# - **Spalte = eine Eigenschaft (Feature), z. B. Alter**
# - **Label = das, was wir vorhersagen wollen (z. B. überlebt oder nicht)**
# - **Trainingsdaten vs. Testdaten:** Bekannte Antworten vs. neue Daten zum Testen
#
# ---
#
# ### 🧹 4. Pandas 101
# - Open-Source-Python-Bibliothek zur effizienten Datenanalyse und -manipulation von DataFrames
# - `read_csv`, `.head()`, `.info()`, `.describe()`
# - Spalten und Zeilen auswählen
# - `groupby()`, `map()`, `dropna()` usw.
# - Datentypen (int, float, string = object)
#
#
# ---
#
# ### 📐 5. Arten von Variablen
#
# - **Numerisch:** z. B. Alter, Fahrpreis
#   → kontinuierlich (Alter: 23.5) vs. diskret (Geschwister: 0, 1, 2, ..)
# - **Kategorisch:** z. B. Geschlecht, Abfahrtsort
# - **Ordinal:** z. B. Ticketklasse (hat eine Reihenfolge)
#
# ---
#
# ### 🧠 6. Was ist ein Modell? Was heißt „trainieren“?
#
# - Modell = eine Funktion, die Vorhersagen trifft
# - Trainieren = Das Modell lernt aus Beispielen, wie Eingaben mit Ausgaben zusammenhängen
# - Danach kann es neue Vorhersagen machen
#
# ---
#
# ### 🧪 7. Klassifikation vs. Regression
#
# - **Klassifikation:** Vorhersage von Kategorien (überlebt / nicht überlebt)
# - **Regression:** Vorhersage von Zahlen (z. B. Hauspreis)
#
# ---
#
# ### 🧰 8. Mini-Crashkurs Scikit-Learn
#
# - Scikit-Learn: Python-Open-Source-Bibliothek, die effiziente Tools für Machine Learning Operationen bietet
# - So funktioniert das meistens:
#
# ```
# model = Modelltyp()
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)
# model.score(X_train, y_train)
# ```

# %% [markdown]
# # **🧭 1 – Problemverständnis & Zieldefinition**
#
# ## 🎯 Ziel dieses Abschnitts
# In diesem Kapitel lernst du, wie man ein Data-Science-Projekt richtig startet: mit einer **präzisen Problemdefinition**.
# Das ist der wichtigste Schritt, bevor wir mit Daten oder Modellen arbeiten.
# Diese Fähigkeit hilft dir bei jedem echten Projekt.
#
# ## ❓ Warum startet man mit einer Problemdefinition?
#
# > Data Science ist keine Magie. Wenn du das Problem nicht verstehst, hilft dir auch kein Modell.
#
# Deshalb beginnt jedes gute Projekt mit ein paar grundlegenden Fragen:
#
# 1. **Was ist das Ziel?** Was soll vorhergesagt oder entschieden werden?
# 2. **Welche Daten stehen zur Verfügung?**
# 3. **Wie sieht Erfolg aus?** Woran erkenne ich, dass meine Lösung gut ist?
#
# 📌 Bevor du irgendetwas codest, solltest du diese Fragen beantworten können.
#
# ## 🛳 Titanic – Unser Fallbeispiel
#
# - Am **15. April 1912** sank die Titanic während ihrer Jungfernfahrt nach einer Kollision mit einem Eisberg.
# - Dabei kamen **1502 von 2224** Passagieren und Besatzungsmitgliedern ums Leben – das entspricht einer **Überlebensrate von ca. 32 %**.
# - Einer der Hauptgründe für das große Ausmaß der Katastrophe war der **Mangel an Rettungsbooten** für alle Personen an Bord.
# - Zwar spielte beim Überleben auch **Zufall oder Glück** eine Rolle, aber bestimmte Gruppen hatten **signifikant bessere Überlebenschancen** – insbesondere:
#   - **Frauen**
#   - **Kinder**
#   - **Passagiere der 1. Klasse**
#
# ## Beschreibung der Titanic-Datensatz-Spalten
#
# | Spalte        | Beschreibung |
# |---------------|--------------|
# | **PassengerId** | Eindeutige Identifikationsnummer jedes Passagiers. Dient zur Zuordnung, hat aber keinen Einfluss auf das Überleben. |
# | **Survived**    | Überlebensstatus des Passagiers: `0 = Nicht überlebt`, `1 = Überlebt`.  |
# | **Pclass**      | Passagierklasse (sozialer und finanzieller Status): <br> `1 = Erste Klasse`, `2 = Zweite Klasse`, `3 = Dritte Klasse`.  |
# | **Name**        | Vollständiger Name des Passagiers, inklusive Anrede (z. B. *Mr.*, *Mrs.*, *Miss*, *Dr.*), was auch Rückschlüsse auf Geschlecht und sozialen Status erlauben kann. |
# | **Sex**         | Geschlecht des Passagiers (`male` oder `female`). Ein starker Prädiktor für das Überleben. |
# | **Age**         | Alter des Passagiers in Jahren. |
# | **SibSp**       | Anzahl an mitreisenden Geschwistern und/oder Ehepartnern an Bord. Hilft beim Erkennen von Familienstrukturen. |
# | **Parch**       | Anzahl an mitreisenden Elternteilen und/oder Kindern. Ebenfalls hilfreich zur Erkennung von Familienreisen. |
# | **Ticket**      | Ticketnummer des Passagiers. |
# | **Fare**        | Preis des Tickets (in britischen Pfund). Korreliert häufig mit `Pclass` – teurere Tickets → höhere Klassen. |
# | **Cabin**       | Kabinennummer. |
# | **Embarked**    | Einschiffungshafen: <br> `C = Cherbourg`, `Q = Queenstown`, `S = Southampton`. Kann sozioökonomische Faktoren widerspiegeln. |
#
#
# Unsere Aufgabe in diesem Workshop:
#
# > **Was könnte man mit Passagierdaten über die Titanic herausfinden?
# ✍️ Überlege selbst: Was wäre spannend oder nützlich zu wissen?**

# %% [markdown]
# ## ✏️ 1. Deine Aufgabe: Definiere das Titanic-Projekt selbst
#
# Nutze die folgenden Zellen, um das Titanic-Problem **aus deiner Sicht** zu beschreiben.
# Das hilft dir, das **"Warum"** hinter dem Projekt zu verstehen.
#
# ### 1️⃣ Was ist das Ziel unseres Projekts?
#
# 🧠 *Was soll das Modell am Ende können?*
# → Schreibe hier deine eigene Problemdefinition.
#
# ### 2️⃣ Welche Daten stehen vermutlich zur Verfügung?
#
# 🔍 *Welche Informationen bekommen wir pro Passagier?*
# → Liste typische Merkmale auf, wie z. B. Alter, Klasse, Name, Geschlecht...
#
# ### 3️⃣ Wer könnte dieses Modell später nutzen und warum?

# %% [markdown]
# # **2 – Daten beschaffen & untersuchen**
#
# > **Ziel dieses Kapitels:**
# > Du lernst, wie man echte Daten in ein Data-Science-Projekt lädt und erste Strukturfragen klärt:
# >
# > – Welche Spalten gibt es?
# > – Welche Datenarten sind enthalten?
# > – Wie vollständig sind die Daten?
#
# ---
#
# ## 2.1 Daten einlesen 📦
#
# Wir arbeiten mit zwei CSV-Dateien:
# - `train.csv` enthält **Passagierdaten mit Überlebens-Label** (0 oder 1),
# - `test.csv` enthält **Passagierdaten ohne Label** – für echte Vorhersagen später.

# %%
# 📥 TODO: Lade die Titanic-Daten als Pandas DataFrame
...

# Datei(en) laden
...
...

# Überblick verschaffen
...

# %% [markdown]
# ## 2.2 Überblick über Struktur & Inhalte 🔍
#
# > ✍️ Aufgabe: Beantworte nach dem Ausführen der Zelle folgende Fragen:
#
# - Wie viele Spalten gibt es?
#
# - Welche Spalten sind numerisch, welche kategorisch (z. B. Text)?
#
# - Gibt es Spalten mit fehlenden Werten (NaN)?

# %%
# 🧾 TODO: Welche Spalten gibt es? Und welche Datenarten?
...

# %% [markdown]
# ## 2.3 Wie vollständig sind die Daten? ⚠️
# > ✍️ Aufgabe:
#
# - Welche Spalten haben besonders viele fehlende Werte?
# - Was bedeutet das für spätere Modellierungsschritte?
# - Würdest du bestimmte Spalten eventuell ausschließen?

# %%
# 🔍 TODO: Zeige Anzahl fehlender Werte pro Spalte
...

# %% [markdown]
# ## 2.4 Verteilungen & Auffälligkeiten 📊
# In diesem Abschnitt schauen wir uns an, wie die Daten verteilt sind – sowohl numerisch als auch kategorisch.
# Wir entdecken dabei mögliche Probleme: Ausreißer, unbrauchbare Spalten oder chaotische Einträge.
# > ✍️ **Aufgabe**:
# Zeige statistische Kennzahlen für numerische Spalten.

# %%
# 📈 Überblick über numerische Spalten
# Zeige statistische Kennzahlen für numerische Spalten
...

# %% [markdown]
# ## 🧠 Reflexionsfragen – Numerisch
# - Gibt es Spalten mit sehr schiefer Verteilung?
# - Gibt es Spalten mit extremen Ausreißern?
# - Welche Spalten zeigen typische Gruppenbildung?

# %%
# 🧾 Überblick über kategorische Spalten
# Zeige Häufigkeiten und Beispiele für kategorische Spalten
...

# %% [markdown]
# ## 🧠 Reflexionsfragen – Kategorisch:
# - Welche Spalten enthalten viele Duplikate?
# - Welche Spalten wirken unübersichtlich oder uneinheitlich?
# - Welche Spalten könnten aussortiert werden?

# %% [markdown]
# # 📚  **3 – Analyse & Muster erkennen**
# **🧭 Ziel dieses Kapitels**
# Du lernst:
# - wie man Auffälligkeiten erkennt (z. B. Alter, Preis, Geschlecht, Klasse)
# - wie man Hypothesen formuliert („Wer hatte höhere Überlebensraten?“)
# - wie man Zusammenhänge zwischen Spalten prüft (Pivot & Visuals)

# %% [markdown]
# ### 🧪 3.1 Korrelation numerischer Merkmale mit Survived

# %%
...


# Diagramm: Überlebensrate je nach Alter
...

# %% [markdown]
# ✍️ Fragen zur Reflexion
# - Welche Altersgruppen hatten die höchste Überlebensrate?
# - Gibt es Altersgruppen mit besonders hoher oder niedriger Dichte?

# %% [markdown]
# ### 🧭 3.2 Pivot: Welche Klassen hatten bessere Chancen?

# %%
# Überlebensrate nach Ticketklasse
...

# %% [markdown]
# 💡 Ergebnis:
# 1. Klasse hatte deutlich höhere Überlebensrate

# %% [markdown]
# ### 📊 3.3 Pivot: Hatten Frauen wirklich bessere Chancen?

# %%
# Überlebensrate nach Ticketklasse
...

# %% [markdown]
# 💡 Ergebnis: Frauen überlebten deutlich häufiger als Männer.

# %% [markdown]
# ### 🧠 3.4 Interaktive Aufgabe – eigene Hypothese testen

# %%
# TODO: Untersuche ein anderes Merkmal, das dich interessiert
...

# %% [markdown]
# **✍️ Deine Frage**:
# Was vermutest du, wie sich dieses Merkmal auf das Überleben auswirkt?
# Teste deine Idee & notiere eine Beobachtung.

# %% [markdown]
# ### ✅ Fazit dieses Kapitels
# Du hast gelernt:
#
# - welche Merkmale stark mit dem Überleben korrelieren
#
# - wie man Zusammenhänge sichtbar macht (Pivot & Visuals)
#
# - warum wir manche Spalten (z. B. Pclass, Sex, Age) später im Modell brauchen

# %% [markdown]
# # 🧼 **4 – Daten bereinigen & vorbereiten**
#
# **Ziel dieses Abschnitts:**
# Wir machen die Daten modellbereit – durch Aufräumen, Umwandeln und Ergänzen.
#
# ## 🔍 Warum ist das wichtig?
# Machine-Learning-Modelle funktionieren nicht gut mit unvollständigen oder unklaren Daten:
#
# - Fehlende Werte müssen sinnvoll ergänzt oder entfernt werden.
# - Textdaten (wie „male“/„female“) müssen in Zahlen umgewandelt werden.
# - Neue hilfreiche Features können aus vorhandenen Daten entstehen (z. B. „Familiengröße“).

# %% [markdown]
# ## 📦 4.1 Spalten löschen, die nichts bringen
# 🧠 Idee: Wir entfernen Spalten, die wenig Aussagekraft haben oder schwer verwertbar sind.
#
# 👉 **Das betrifft**:
# ...

# %%
# TODO: Spalten löschen, die wir nicht direkt brauchen
...

# %% [markdown]
# ## 🎩 4.2 Titel aus dem Namen extrahieren
#
# 🧠 Idee: In der Spalte Name stecken Titel wie Mr, Miss, Dr, etc.
# Diese geben Hinweise auf Geschlecht, Alter oder soziale Stellung.

# %%
# Titel aus dem Namen extrahieren
...

# Häufigkeit pro Titel anzeigen
...

# %% [markdown]
# >✍️ Aufgabe: Welche Titel gibt es? Welche erscheinen „selten“?

# %% [markdown]
# ## 🧹 4.3 Titel vereinfachen

# %%
# Seltene Titel zusammenfassen
...

# %% [markdown]
# ## 🔢 4.4 Titel als Zahl kodieren

# %%
# Titel zu Zahlen umwandeln
...

# Danach: 'Name' löschen
...

# %% [markdown]
# ## 🚻 4.5 Geschlecht (Sex) in Zahlen umwandeln

# %%
...

# %% [markdown]
# ✅ **Warum wichtig?**
# Maschinenlernen-Modelle können nicht mit Strings wie "male"/"female" umgehen – sie brauchen numerische Werte.

# %% [markdown]
# ## 4.6 Fehlende Werte bei "Age" (Alter) auffüllen

# %%
# Strategie: Median nach Pclass und Sex kombinieren

...

...

# %% [markdown]
# 📌 Hinweis: Hier kombinieren wir zwei vorhandene Spalten, um einen sinnvollen Wert für fehlendes Alter abzuleiten.

# %% [markdown]
# ## 4.7 Alter in Kategorien einteilen ("Age Binning")

# %%
...

# %% [markdown]
# 🎯 Ziel: Aus kontinuierlichem Alter ein **kategorisches Merkmal** erzeugen, das Modelle besser verstehen können.

# %%
# Alter in Kategorien umwandeln
...

# %% [markdown]
# ## 4.8 Fehlende Werte in "Embarked" auffüllen

# %%
# Häufigster Wert verwenden
...

# In Zahlen umwandeln
...

# %% [markdown]
# ## 4.9 Familiengröße erstellen (SibSp + Parch + man selbst)

# %%
...

# %% [markdown]
# ## 4.10 Feature "IsAlone" (1 = alleine, 0 = in Begleitung)

# %%
...

# %%
# Alte Spalten entfernen
...

# %% [markdown]
# ## ✅ 4.11 Finaler Check: Sind alle Daten numerisch und vollständig?

# %%
...

# %% [markdown]
# ## 🟢 Zusammenfassung: Das hast du jetzt gemacht
#
# - Geschlecht, Alter, Hafen, Preis **in Zahlen umgewandelt**
# - Fehlende Werte **sinnvoll ergänzt**
# - Neue Features: `IsAlone`
# - Feature-Binning: `Age`, `Fare`
# - Redundante Features entfernt: `SibSp`, `Parch`, `FareBand`
#
# 📦 Dein Datensatz ist jetzt bereit für das Modelltraining!

# %% [markdown]
# # 🧠 **5 – Modelle trainieren & Vorhersagen treffen**
#
# ## 🎯 Ziel dieses Abschnitts
# Jetzt sind unsere Daten sauber und modellbereit – Zeit für den spannenden Teil:
#
# > **Kann ein Machine-Learning-Modell vorhersagen, wer die Titanic-Katastrophe überlebt hätte?**
#
# Wir testen verschiedene **klassische Algorithmen** und vergleichen, welcher am besten funktioniert.

# %% [markdown]
# ## 📚 5.1 Welche Art von Problem liegt vor?
#
# ...

# %%
# 🧪 Trainingsdaten und Testdaten vorbereiten

...

# %% [markdown]
# ## ⚙️ 5.2 Los geht’s: Verschiedene Modelle ausprobieren
#
# Wir testen die folgenden Algorithmen:
#
# - 📈 Logistische Regression
# - 🤖 Entscheidungsbaum & Random Forest
# - 🔍 K-Nearest-Neighbors
# - 🧠 Perceptron
# - 💡 Naive Bayes
# - 🧩 Support Vector Machine
# - 📐 Stochastic Gradient Descent

# %% [markdown]
# ### 🔢 5.2.1 Logistische Regression
#
# Es berechnet Wahrscheinlichkeiten für zwei Klassen (z. B. Überlebt ja/nein) mit einer sogenannten S-Kurve.
# 💡 Oft der erste Startpunkt, wenn man Klassifikation testen will.

# %%
...

...

# %% [markdown]
# ### 🧠 5.2.2 Entscheidungsbaum
# Es erstellt eine Art Flussdiagramm mit JA/NEIN-Fragen, z. B. "Ist die Person weiblich?"
# 💡 Sehr gut verständlich und visuell interpretierbar.

# %%
...

...

# %% [markdown]
# ### 🌲 5.2.3 Random Forest
# Es baut viele Entscheidungsbäume und lässt sie abstimmen.
# 💡 Robust, genau, sehr beliebt für erste Tests.

# %%
...

...

# %% [markdown]
# ### 🤝 5.2.4 K-Nearest Neighbors (k-NN)
# Es schaut sich die "nächsten Nachbarn" einer Person im Datensatz an und stimmt ab, was mit ihr passieren würde.
# 💡 Einfach, aber kann bei vielen Daten langsam werden.

# %%
...

...

# %% [markdown]
# ### 🧠 5.2.5 Perceptron
# Ein einfaches künstliches Neuron, das bei jedem Fehler seine "Gewichte" anpasst.
# 💡 Historisch wichtig, aber oft weniger genau als modernere Modelle.

# %%
...

...

# %% [markdown]
# ### 🧮 5.2.6 Naive Bayes
# Es basiert auf Wahrscheinlichkeiten und geht davon aus, dass alle Merkmale unabhängig voneinander sind (was oft nicht stimmt).
# 💡 Schnell, gut bei Text oder einfachen Problemen.

# %%
...

...

# %% [markdown]
# ### 🧩 5.2.7 Support Vector Machine (SVM)
# Es versucht, eine klare Grenze zwischen den Klassen zu finden – möglichst weit weg von allen Punkten.
# 💡 Gut bei komplexen Problemen mit klarer Trennlinie.

# %%
...

...

# %% [markdown]
# ### 📐 5.2.8 Stochastic Gradient Descent
# Es ist ein schneller Optimierungsalgorithmus, der besonders gut bei großen Datenmengen funktioniert.
# 💡 Für lineare Probleme geeignet – sehr leichtgewichtig.

# %%
...

...

# %% [markdown]
# ## 🏆 5.3 Modellvergleich – Wer ist der Beste?
#
# Wir vergleichen alle Ergebnisse in einer übersichtlichen Tabelle.

# %%
...

...

# %% [markdown]
# ## 🤔 5.4 Fazit
#
# - Das **beste Modell** ist meist der **Random Forest** 🌲 – stark, robust, flexibel.
# - Manchmal ist aber auch **ein einfaches Modell** wie logistische Regression nützlich, wenn Interpretierbarkeit zählt.
# - 🔬 Weitere Schritte (optional):
#   - Hyperparameter-Tuning
#   - Cross-Validation
#   - Feature-Importance analysieren
#   - Testdaten einreichen (z. B. bei Kaggle)
#
# 🎉 Du hast erfolgreich deinen ersten Machine-Learning-Workflow abgeschlossen!
